# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("../data/raw/olist_orders_dataset.csv")

# %%
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
df.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
ind=np.where(df['order_delivered_customer_date'].isna())

# %%
df=df.drop(ind[0],axis=0).reset_index()

# %%
df.isnull().sum()
# Out:
# index                             0
# order_id                          0
# customer_id                       0
# order_status                      0
# order_purchase_timestamp          0
# order_approved_at                14
# order_delivered_carrier_date      1
# order_delivered_customer_date     0
# order_estimated_delivery_date     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96476 entries, 0 to 96475
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   index                          96476 non-null  int64
#  1   order_id                       96476 non-null  object
#  2   customer_id                    96476 non-null  object
#  3   order_status                   96476 non-null  object
#  4   order_purchase_timestamp       96476 non-null  object
#  5   order_approved_at              96462 non-null  object
#  6   order_delivered_carrier_date   96475 non-null  object
#  7   order_delivered_customer_date  96476 non-null  object
#  8   order_estimated_delivery_date  96476 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 6.6+ MB

# %%
ind=np.where(df['order_approved_at'].isna())

# %%
len(ind[0])
# Out:
# 14

# %%
df=df.drop(ind[0],axis=0).reset_index()

# %%
df.isna().sum()
# Out:
# level_0                          0
# index                            0
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     1
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %%
df=df[df['order_delivered_carrier_date'].notna()]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 96461 entries, 0 to 96461
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   level_0                        96461 non-null  int64
#  1   index                          96461 non-null  int64
#  2   order_id                       96461 non-null  object
#  3   customer_id                    96461 non-null  object
#  4   order_status                   96461 non-null  object
#  5   order_purchase_timestamp       96461 non-null  object
#  6   order_approved_at              96461 non-null  object
#  7   order_delivered_carrier_date   96461 non-null  object
#  8   order_delivered_customer_date  96461 non-null  object
#  9   order_estimated_delivery_date  96461 non-null  object
# dtypes: int64(2), object(8)
# memory usage: 8.1+ MB

# %%
df.to_parquet("../data/clean/clean_olist_orders_dataset.parquet")
